# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mpl_toolkits
# %matplotlib inline

# %%
data = pd.read_csv("data/monsters.csv")

# %%
data.head()
# Out:
#    Unnamed: 0                       _id               index  \
# 0           0  5f2329ad0b1bb138c59411ee             aboleth
# 1           1  5f2329ad0b1bb138c59411ef             acolyte
# 2           2  5f2329ad0b1bb138c59411f1  adult-black-dragon
# 3           3  5f2329ad0b1bb138c59411f0   adult-blue-dragon
# 4           4  5f2329ad0b1bb138c59411f2  adult-brass-dragon
#
#                  name    size        type   subtype      alignment  \
# 0             Aboleth   Large  aberration       NaN    lawful evil
# 1             Acolyte  Medium    humanoid  any race  any alignment
# 2  Adult Black Dragon    Huge      dragon       NaN   chaotic evil
# 3   Adult Blue Dragon    Huge      dragon       NaN    lawful evil
# 4  Adult Brass Dragon    Huge      dragon       NaN   chaotic good
#
#    armor_class  hit_points  ... condition_immunities  \
# 0           17         135  ...                   []
# 1           10           9  ...                   []
# 2           19         195  ...                   []
# 3           19         225  ...                   []
# 4           18         172  ...                   []
#
#                                               senses  \
# 0  {'darkvision': '120 ft.', 'passive_perception'...
# 1                         {'passive_perception': 12}
# 2  {'blindsight': '60 ft.', 'darkvision': '120 ft...
# 3  {'blindsight': '60 ft.', 'darkvision': '120 ft...
# 4  {'blindsight': '60 ft.', 'darkvision': '120 ft...
#
#                            languages  challenge_rating  \
# 0     Deep Speech, telepathy 120 ft.             10.00
# 1  any one language (usually Common)              0.25
# 2                   Common, Draconic             14.00
# 3                   Common, Draconic             16.00
# 4                   Common, Draconic             13.00
#
#                                    special_abilities  \
# 0  [{'name': 'Amphibious', 'desc': 'The aboleth c...
# 1  [{'name': 'Spellcasting', 'desc': 'The acolyte...
# 2  [{'name': 'Amphibious', 'desc': 'The dragon ca...
# 3  [{'name': 'Legendary Resistance', 'desc': 'If ...
# 4  [{'name': 'Legendary Resistance', 'desc': 'If ...
#
#                                              actions  \
# 0  [{'name': 'Multiattack', 'desc': 'The aboleth ...
# 1  [{'name': 'Club', 'desc': 'Melee Weapon Attack...
# 2  [{'name': 'Multiattack', 'desc': 'The dragon c...
# 3  [{'name': 'Multiattack', 'desc': 'The dragon c...
# 4  [{'name': 'Multiattack', 'desc': 'The dragon c...
#
#                                    legendary_actions  \
# 0  [{'name': 'Detect', 'desc': 'The aboleth makes...
# 1                                                NaN
# 2  [{'name': 'Detect', 'desc': 'The dragon makes ...
# 3  [{'name': 'Detect', 'desc': 'The dragon makes ...
# 4                                                NaN
#
#                                 url reactions other_speeds
# 0             /api/monsters/aboleth       NaN          NaN
# 1             /api/monsters/acolyte       NaN          NaN
# 2  /api/monsters/adult-black-dragon       NaN          NaN
# 3   /api/monsters/adult-blue-dragon       NaN          NaN
# 4  /api/monsters/adult-brass-dragon       NaN          NaN
#
# [5 rows x 32 columns]

# %%
data.describe()
# Out:
#        Unnamed: 0  armor_class  hit_points    strength   dexterity  \
# count  322.000000   322.000000  322.000000  322.000000  322.000000
# mean   160.500000    14.031056   81.291925   15.161491   12.624224
# std     93.097619     3.256285   99.425430    6.736612    3.202185
# min      0.000000     5.000000    1.000000    1.000000    1.000000
# 25%     80.250000    12.000000   18.250000   11.000000   10.000000
# 50%    160.500000    13.000000   45.000000   16.000000   13.000000
# 75%    240.750000    17.000000  114.000000   19.000000   15.000000
# max    321.000000    25.000000  676.000000   30.000000   28.000000
#
#        constitution  intelligence      wisdom    charisma  challenge_rating
# count    322.000000    322.000000  322.000000  322.000000        322.000000
# mean      15.080745      7.754658   11.686335    9.683230          4.543090
# std        4.506105      5.704460    2.934020    5.789584          5.892224
# min        8.000000      1.000000    3.000000    1.000000          0.000000
# 25%       12.000000      2.000000   10.000000    5.000000          0.500000
# 50%       14.000000      7.000000   12.000000    8.000000          2.000000
# 75%       18.000000     12.000000   13.000000   14.000000          6.000000
# max       30.000000     25.000000   25.000000   30.000000         30.000000

# %%
train1 = data[['armor_class','hit_points','strength','dexterity','constitution','intelligence','wisdom']]

# %%
train1.head()
# Out:
#    armor_class  hit_points  strength  dexterity  constitution  intelligence  \
# 0           17         135        21          9            15            18
# 1           10           9        10         10            10            10
# 2           19         195        23         14            21            14
# 3           19         225        25         10            23            16
# 4           18         172        23         10            21            14
#
#    wisdom
# 0      15
# 1      14
# 2      13
# 3      15
# 4      13

# %%
from sklearn.linear_model import LinearRegression
reg = LinearRegression()
labels = data['challenge_rating']

# %%
from sklearn.model_selection import train_test_split
x_train , x_test , y_train , y_test = train_test_split(train1 , labels , test_size = 0.10,random_state =2)

# %%
reg.fit(x_train,y_train)
reg.score(x_test,y_test)
# Out:
# 0.9465535174461516

# %%
y_pred = reg.predict(train1)

# %%
print('predicted response:', y_pred, sep='\n')
# Out:
# predicted response:
# [ 8.71997387e+00  1.07427410e+00  1.15478423e+01  1.36897756e+01
#   1.05011072e+01  1.31344746e+01  1.17930072e+01  1.51542617e+01
#   1.29129437e+01  1.48958581e+01  1.43405571e+01  1.10400623e+01
#   4.31812344e+00  2.03081207e+01  2.60381531e+01  1.71162779e+01
#   2.44576809e+01  2.02969928e+01  2.90191829e+01  2.17920341e+01
#   2.87607794e+01  2.62405669e+01  1.78311543e+01  1.24813573e+01
#   5.23510451e-01  1.69525070e+00  1.18585403e+00  6.83894811e+00
#   5.08473832e+00  9.73397147e-01  3.30937954e+00  5.55507929e-02
#   3.76318973e+00  2.61079150e-01  2.26707120e-01  1.55936690e+01
#   1.01258212e+00  4.39364309e+00  7.17246071e+00  1.72871831e+00
#  -2.12415416e-01  3.08304701e+00  8.88830628e+00  4.12062384e+00
#   7.01482269e-01  2.68302828e+00  2.22411519e+00  1.96162077e+00
#   5.99932275e-01  4.02348655e+00 -3.69457106e-01  9.10022078e+00
